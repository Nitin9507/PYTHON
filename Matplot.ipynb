# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(4,5))
plt.plot(np.array([1,2,3,4,5,6,7,8]))
plt.title("first diagram")
plt.xlabel("Inc-->")
plt.ylabel("Inc-->")
plt.show()

# %%
x=[1,3,5,7,9]
y=[2,4,16,8,10]

fig, a=plt.subplots(figsize=(5,5))
a.plot(x,y, marker='o')
plt.show()

# %%
x= np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
fig, a=plt.subplots()
a.plot(x, x**2)
plt.show()

# %%
fig, ax= plt.subplots()
ax.scatter(x, np.cos(x))

# %%
Data={
    "A":10,
    "B":20,
    "C":15,
}

fig, a=plt.subplots()
a.bar(Data.keys(),Data.values(), color='green', edgecolor='BLack')
plt.title("Bar")
plt.show()

# %%
Data={
    "A":10,
    "B":20,
    "C":15,
}

fig, a=plt.subplots()
a.barh(list(Data.keys()),list(Data.values()))
plt.title("Bar")
plt.show()

# %%
x= np.random.randn(15)
fig, a=plt.subplots()
a.hist(x)
plt.show()

# %%
x= np.random.random(153)
fig, a=plt.subplots()
a.hist(x, bins=5,edgecolor='Black')
plt.show()

# %%
x= np.random.random(153)
fig, a=plt.subplots()
a.boxplot(x)
plt.show()

# %%
import pandas as pd
data={
    "x":[1,2,3,4,5],
    "y1":[2,3,5,7,11],
    "y2":[1,2,4,6,9],
}
df= pd.DataFrame(data)
df.plot(x='x', kind='area', stacked=False)
# Out:
# <Axes: xlabel='x'>

# %%
fig, ((a,b),(c,d))= plt.subplots(nrows=2,
                                 ncols=2,
                                 figsize=(7,6))
a.plot(x, x*2)
a.set_title("Plot Chart")

b.scatter(np.random.random(10),np.random.random(10))
b.set_title("Scatter Chart")

c.bar(Data.keys(), Data.values())
c.set_title("Bar Chart")

d.hist(np.random.randn(1000))
d.set_title("Hist Chart")

plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.show()

# %%
data={
    'make':np.random.choice(["Toyota", "BMW", "Audi", "Dodge", "Lexus"],20),
    'Year':np.random.choice([1980,1982,1995,1975,1977],20),
    'Door':np.random.choice([4,2],20),
    'odometer':np.random.randint(10,1000,20),
    'price':np.random.randint(100000,1000000,20)
}
df= pd.DataFrame(data)
df
# Out:
#       make  Year  Door  odometer   price
# 0   Toyota  1975     4       174  760486
# 1      BMW  1980     4       273  160483
# 2    Dodge  1995     4       455  608073
# 3    Dodge  1980     2       879  363184
# 4    Lexus  1982     2       879  675496
# 5      BMW  1977     4       217  575780
# 6      BMW  1982     2       791  345763
# 7      BMW  1975     2       644  770749
# 8    Lexus  1995     2       151  550775
# 9   Toyota  1977     4       277  415039
# 10   Dodge  1975     4        64  493813
# 11   Dodge  1975     2       547  623005
# 12  Toyota  1977     4       613  879575
# 13   Dodge  1975     4        69  935027
# 14   Lexus  1977     2       494  906479
# 15   Lexus  1980     4       709  201606
# 16     BMW  1980     4       751  954297
# 17   Lexus  1977     2       211  432328
# 18  Toyota  1980     2       267  278469
# 19     BMW  1977     2       332  757703

# %%
import pandas as pd
import numpy as np
s=pd.Series(np.random.randn(1000))
index=pd.date_range("01-01-2024", periods=1000)

s
# Out:
# 0      0.105015
# 1     -0.757961
# 2      0.530309
# 3      0.650480
# 4      0.240020
#          ...
# 995   -0.423531
# 996    1.176522
# 997   -0.920808
# 998   -0.563451
# 999    0.619117
# Length: 1000, dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.cumsum()
# Out:
# 0       0.105015
# 1      -0.652946
# 2      -0.122637
# 3       0.527842
# 4       0.767862
#          ...
# 995    15.245891
# 996    16.422413
# 997    15.501605
# 998    14.938154
# 999    15.557271
# Length: 1000, dtype: float64

# %%
s.cumsum().plot(kind="line")
# Out:
# <Axes: >

# %%
df
# Out:
#       make  Year  Door  odometer   price
# 0   Toyota  1975     4       174  760486
# 1      BMW  1980     4       273  160483
# 2    Dodge  1995     4       455  608073
# 3    Dodge  1980     2       879  363184
# 4    Lexus  1982     2       879  675496
# 5      BMW  1977     4       217  575780
# 6      BMW  1982     2       791  345763
# 7      BMW  1975     2       644  770749
# 8    Lexus  1995     2       151  550775
# 9   Toyota  1977     4       277  415039
# 10   Dodge  1975     4        64  493813
# 11   Dodge  1975     2       547  623005
# 12  Toyota  1977     4       613  879575
# 13   Dodge  1975     4        69  935027
# 14   Lexus  1977     2       494  906479
# 15   Lexus  1980     4       709  201606
# 16     BMW  1980     4       751  954297
# 17   Lexus  1977     2       211  432328
# 18  Toyota  1980     2       267  278469
# 19     BMW  1977     2       332  757703

# %%
df.plot(x="odometer", y="price", kind="scatter")
# Out:
# <Axes: xlabel='odometer', ylabel='price'>

# %%
df.plot(x="make", kind="bar")
# Out:
# <Axes: xlabel='make'>

# %%
df.plot(x="make", y="odometer", kind="bar")
# Out:
# <Axes: xlabel='make'>

# %%
df.plot(x="make", kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode=[0.2,0,0,0]
plt.pie(y, labels=mylabels, startangle=120, explode=myexplode, shadow=True)
plt.legend()
plt.show()

# %%
x=np.array([0,20])
y=np.array([0,100])
plt.plot(x,y)
plt.show()

# %%
x=([1,5,9,7,5,3])
plt.plot(x, marker = "*",ms=20, mfc="red", linewidth=20)
plt.show()

# %%
y = np.array([3, 8, 1, 10])

plt.plot(y, 'o:m')
plt.show()

# %%
x = np.array([70, 75, 80, 85, 120, 95, 100, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.title("Sports Watch Data",loc="left", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.grid(axis="x",color="blue",linestyle="--")
plt.show()

# %%
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([50,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = 'red')
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([9,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'blue')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,99,111,86,130,87,94,78,77,88,150])
colors=np.array(["red","black","orange","blue","green","cyan","gray","beige","yellow","purple","magenta","hotpink","pink"])
plt.scatter(x,y, c=colors)
plt.colorbar()
plt.show()
