# %%
# !pip install -U seaborn

# %%
import seaborn as sc

# %%
import matplotlib.pyplot as plt

# %%
df = sc.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sc.histplot(df["tip"], kde=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
s= sc.load_dataset("tips")
sc.scatterplot(x="total_bill", y="tip", data=s)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
s= sc.load_dataset("tips")
sc.scatterplot(x="total_bill", y="tip", hue="sex", size="size", data=s)
plt.title("Relationship between Total Bill and Tip")
plt.show()

# %%
sc.histplot(df['sex'], color="gray", edgecolor="Blue")
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
fmri= sc.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sc.lineplot(x="timepoint", y="signal", marker= "*", ms=10, mfc="red", linestyle="--", data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sc.lineplot(x="timepoint", y="signal", hue="event",marker= "*", ms=10, mfc="red", style="region",linestyle="--", data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
df= sc.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sc.barplot(x="age", y="class", color="skyblue", hue="sex", errorbar=None, palette="muted", data=df)
# Out:
# <Axes: xlabel='age', ylabel='class'>

# %%
p= sc.load_dataset("iris")
p
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sc.histplot(x="sepal_width", y="petal_width", color="Black", edgecolor="red", data=p)
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
data= sc.load_dataset("penguins")
sc.kdeplot(data['body_mass_g'], fill=True)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sc.rugplot(data['body_mass_g'])
# Out:
# <Axes: xlabel='body_mass_g'>

# %%
sc.ecdfplot(data['body_mass_g'])
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Proportion'>

# %%
sc.pairplot(data)

# %%
sc.jointplot(data,kind="scatter", x="bill_length_mm", y="bill_depth_mm")

# %%
sc.violinplot(data, x="species", y="body_mass_g")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
tip= sc.load_dataset("tips")
sc.boxplot(x="day", y="total_bill", data=tip)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sc.boxplot(x="day", y="total_bill", hue="time", data=tip, palette="Set3", linewidth=3, fliersize=5)
plt.show()

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip = tip.drop(columns=["sex" , "smoker" , "day","time"])
corr =tip.corr()
sc.heatmap(corr)
# Out:
# <Axes: >

# %%
i = sc.load_dataset("Iris")
sc.pairplot(data=i, kind="kde")

# %%
i = sc.load_dataset("Iris")
sc.pairplot(data=i, diag_kind="kde")
